# %% [markdown]
# # Mask-Guided InstructPix2Pix (Colab Run)
# This notebook installs the dependencies and runs the mask-blended InstructPix2Pix pipeline with the provided scripts. Upload this folder to Colab and execute each cell sequentially.
#
# You can optionally download `results/` afterward for use in the final report.

# %%
# !pip install -r requirements.txt

# %%
# !python project_run.py

# %%
# !python evaluate_metrics.py

# %%
# !ls -R results
